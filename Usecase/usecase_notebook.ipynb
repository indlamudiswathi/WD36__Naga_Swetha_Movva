# %% [markdown]
# #**DATA BRICKS DEVELOPER**
# ##Usecase
# ###<span style="color:yellow;">Swetha Movva</span>
# <img src='https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png'>

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.volume2

# %%
import requests
data =requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
dbutils.fs.put("dbfs:/Volumes/workspace/default/volume1/mobile_os_usage.csv",data.text)

# %%
# %fs ls "/Volumes/workspace/default/volume2"

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/volume2/mobile_os_usage.csv",header=True)
display(df1)

# %%
# %python
df1 = df1.withColumnRenamed("Mobile Operating System", "mobile_operating_system") \
         .withColumnRenamed("Percent of Usage", "percent_of_usage")

df1.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# %%
# %python
df=spark.read.table("default.mobile_os_usage")
print(df)

# %%
# %python
res=("hello world")
print(res.upper())

# %%
# %python
# %pip install pandas

# %%
# %python
import pandas as pd
df1=pd.read_csv("/Volumes/workspace/default/volume2/mobile_os_usage.csv")
print(df1)

# %%
# %sh
echo "Magic commands tasks completed"
